# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('campus.csv', encoding='latin-1')

# %%
data
# Out:
#             personality  University name  Z-core  \
# 0                  Open           Ruhuna  0.8890
# 1                  Open           Ruhuna  0.6900
# 2                  Open           Ruhuna  0.7892
# 3     Conscientiousness           Ruhuna  0.7900
# 4     Conscientiousness           Ruhuna  0.8400
# ...                 ...              ...     ...
# 1509      Extraversion   Open University     NaN
# 1510      Extraversion   Open University     NaN
# 1511      Extraversion   Open University     NaN
# 1512      Extraversion   Open University     NaN
# 1513      Extraversion   Open University     NaN
#
#                                 Degree Name     District O/L Maths   \
# 0                          Physical Science     Kalutara          A
# 1                          Physical Science       Matale          B
# 2                          Physical Science   Hambantota          A
# 3                          Physical Science       Matara          B
# ...

# %%
data.shape
# Out:
# (1514, 13)

# %%
data['personality'].value_counts()
# Out:
# Open                 429
# Conscientiousness    429
# Extraversion         391
# Agreeableness        125
# Neuroticism           10
# Name: personality, dtype: int64

# %%
data['personality'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1509    False
# 1510    False
# 1511    False
# 1512    False
# 1513    False
# Name: personality, Length: 1514, dtype: bool

# %%
sns.heatmap(data.isnull(),yticklabels=False, cmap="viridis")
# Out:
# <Axes: >

# %%
data["personality"].fillna("Neuroticism", inplace = True)

# %%
def personality_data(value):
    res=""
    if value=="Open":
        res=1
    elif value=="Conscientiousness":
        res=2
    elif value=="Extraversion ":
        res=3
    elif value=="Agreeableness":
        res=4
    elif value=="Neuroticism":
        res=5
        
    return res

# %%
data['personality'] = data['personality'].apply(personality_data)

# %%
sns.heatmap(data.isnull(),yticklabels=False, cmap="viridis")
# Out:
# <Axes: >

# %%
data["Z-core"].fillna(0, inplace = True)

# %%
sns.heatmap(data.isnull(),yticklabels=False, cmap="viridis")
# Out:
# <Axes: >

# %%
data["O/L Science"]
# Out:
# 0       A
# 1       C
# 2       B
# 3       A
# 4       B
#        ..
# 1509    A
# 1510    A
# 1511    A
# 1512    A
# 1513    A
# Name: O/L Science, Length: 1514, dtype: object

# %%
data['O/L Science'].value_counts()
# Out:
# A    1102
# B     302
# C     107
# Name: O/L Science, dtype: int64

# %%
data["O/L Science"].fillna("S", inplace = True)

# %%
sns.heatmap(data.isnull(),yticklabels=False, cmap="viridis")
# Out:
# <Axes: >

# %%
data["A/L Bio"].fillna("N", inplace = True)
data["A/L Combine Maths"].fillna("N", inplace = True)
data["A/L Chemistry"].fillna("N", inplace = True)
data["A/L Physics "].fillna("N", inplace = True)

# %%
sns.heatmap(data.isnull(),yticklabels=False, cmap="viridis")
# Out:
# <Axes: >

# %%
data["A/L Physics"] = data["A/L Physics "]

# %%
data
# Out:
#       personality  University name  Z-core  \
# 0               1           Ruhuna  0.8890
# 1               1           Ruhuna  0.6900
# 2               1           Ruhuna  0.7892
# 3               2           Ruhuna  0.7900
# 4               2           Ruhuna  0.8400
# ...           ...              ...     ...
# 1509            3  Open University  0.0000
# 1510            3  Open University  0.0000
# 1511            3  Open University  0.0000
# 1512            3  Open University  0.0000
# 1513            3  Open University  0.0000
#
#                                 Degree Name     District O/L Maths   \
# 0                          Physical Science     Kalutara          A
# 1                          Physical Science       Matale          B
# 2                          Physical Science   Hambantota          A
# 3                          Physical Science       Matara          B
# 4                          Physical Science       Matara          A
# ...

# %%
data = data.drop(columns=['A/L Physics '])

# %%
data['District'].value_counts()
# Out:
# Colombo         279
# Rathnapura      139
# Kandy           116
# Galle           112
# Gampaha         102
# Matara           85
# Kalutara         75
# Hambantota       75
# Monaragala       67
# Badulla          48
# Kagalle          37
# Anuradhapura     34
# Mullaitivu       27
# Vavuniya         27
# Trincomalee      27
# Puttalam         27
# Polonnaruwa      27
# Nuwara Eliya     27
# Kilinochchi      27
# Mannar           27
# Kurunegala       27
# Jaffna           27
# Batticaloa       27
# Matale           22
# Ampara           21
# Mathara           5
# Name: District, dtype: int64

# %%
data['District']=data['District'].str.replace('Mathara','Matara')

# %%
data['District'].value_counts()
# Out:
# Colombo         279
# Rathnapura      139
# Kandy           116
# Galle           112
# Gampaha         102
# Matara           90
# Kalutara         75
# Hambantota       75
# Monaragala       67
# Badulla          48
# Kagalle          37
# Anuradhapura     34
# Mullaitivu       27
# Vavuniya         27
# Trincomalee      27
# Puttalam         27
# Polonnaruwa      27
# Nuwara Eliya     27
# Kurunegala       27
# Mannar           27
# Kilinochchi      27
# Jaffna           27
# Batticaloa       27
# Matale           22
# Ampara           21
# Name: District, dtype: int64

# %%
def district_data(value):
    res=""
    if value=="Colombo":
        res=1
    elif value=="Rathnapura":
        res=2
    elif value=="Kandy":
        res=3
    elif value=="Galle":
        res=4
    elif value=="Gampaha":
        res=5
    elif value=="Matara":
        res=6
    elif value=="Kalutara":
        res=7
    elif value=="Hambantota":
        res=8
    elif value=="Monaragala":
        res=9
    elif value=="Badulla":
        res=10
    elif value=="Kagalle":
        res=11
    elif value=="Anuradhapura":
        res=12
    elif value=="Mullaitivu":
        res=13
    elif value=="Vavuniya":
        res=14
    elif value=="Trincomalee":
        res=15
    elif value=="Puttalam":
        res=16
    elif value=="Polonnaruwa":
        res=17
    elif value=="Nuwara Eliya":
        res=18
    elif value=="Mannar":
        res=19
    elif value=="Kilinochchi":
        res=20
    elif value=="Jaffna":
        res=21
    elif value=="Batticaloa":
        res=22
    elif value=="Matale":
        res=23
    elif value=="Ampara":
        res=24
    elif value=="Kurunegala":
        res=25
        
    return res

# %%
data['District'] = data['District'].apply(district_data)

# %%
data
# Out:
#       personality  University name  Z-core  \
# 0               1           Ruhuna  0.8890
# 1               1           Ruhuna  0.6900
# 2               1           Ruhuna  0.7892
# 3               2           Ruhuna  0.7900
# 4               2           Ruhuna  0.8400
# ...           ...              ...     ...
# 1509            3  Open University  0.0000
# 1510            3  Open University  0.0000
# 1511            3  Open University  0.0000
# 1512            3  Open University  0.0000
# 1513            3  Open University  0.0000
#
#                                 Degree Name  District O/L Maths  O/L Science  \
# 0                          Physical Science         7          A           A
# 1                          Physical Science        23          B           C
# 2                          Physical Science         8          A           B
# 3                          Physical Science         6          B           A
# ...

# %%
data['University name'].value_counts()
# Out:
# SLIIT              535
# Ruhuna             411
# Open University    344
# Moratuwa           224
# Name: University name, dtype: int64

# %%
data['University']=data['University name']+"-"+data['Degree Name']

# %%
data=data.drop({'University name','Degree Name'}, axis=1)

# %%
data['University'].value_counts()
# Out:
# Ruhuna-Physical Science                                       225
# Ruhuna-Biological Science                                     146
# SLIIT-IT Special                                              113
# Open University-Bachelor of Science honours in Physics        109
# SLIIT-Cyber Security                                          103
# SLIIT-Humanities & Science                                     92
# SLIIT-Network Engineering                                      89
# Open University-Bachelor of Science Honours in Chemistry       88
# Moratuwa-Architecture                                          77
# Open University-Bachelor of Science Honours in?Botany          76
# Moratuwa-IT                                                    74
# Moratuwa-Engineering                                           73
# SLIIT-Software Engineering                                     73
# Open University-Bachelor of Science Honours in Mathematics     69
# ...

# %%
def university_data(value):
    res=20
    if value=="Ruhuna-Physical Science":
        res=1
    elif value=="Ruhuna-Biological Science":
        res=2
    elif value=="SLIIT-IT Special":
        res=3
    elif value=="Open University-Bachelor of Science honours in Physics":
        res=4
    elif value=="SLIIT-Cyber Security":
        res=5
    elif value=="SLIIT-Humanities & Science":
        res=6
    elif value=="SLIIT-Network Engineering":
        res=7
    elif value=="Open University-Bachelor of Science Honours in Chemistry":
        res=8
    elif value=="Moratuwa-Architecture":
        res=9
    elif value=="Open University-Bachelor of Science Honours in?Botany":
        res=10
    elif value=="Moratuwa-IT":
        res=11
    elif value=="Moratuwa-IT":
        res=12
    elif value=="SLIIT-Software Engineering":
        res=13
    elif value=="Open University-Bachelor of Science Honours in Mathematics":
        res=14
    elif value=="SLIIT-Engineering":
        res=15
    elif value=="Ruhuna-Medicine":
        res=16
    elif value=="SLIIT-Computing":
        res=17
    elif value=="Open University-IT":
        res=18
    elif value=="Open University-Biological Science":
        res=19
    elif value=="Ruhuna-Engineering":
        res=20
    elif value=="Ruhuna-Computing":
        res=21
        
    return res

# %%
data['University'] = data['University'].apply(university_data)

# %%
data['University'].value_counts()
# Out:
# 1     225
# 2     146
# 3     113
# 4     109
# 5     103
# 6      92
# 7      89
# 8      88
# 9      77
# 10     76
# 20     74
# 11     74
# 13     73
# 14     69
# 15     61
# 16     38
# 17      4
# 19      1
# 21      1
# 18      1
# Name: University, dtype: int64

# %%
data
# Out:
#       personality  Z-core  District O/L Maths  O/L Science O/L  English   \
# 0               1  0.8890         7          A           A             C
# 1               1  0.6900        23          B           C             B
# 2               1  0.7892         8          A           B             C
# 3               2  0.7900         6          B           A             A
# 4               2  0.8400         6          A           B             A
# ...           ...     ...       ...        ...         ...           ...
# 1509            3  0.0000        17          A           A             A
# 1510            3  0.0000        16          B           A             A
# 1511            3  0.0000        15          B           A             A
# 1512            3  0.0000        14          B           A             A
# 1513            3  0.0000         1          B           A             A
#
#      A/L Combine Maths A/L Bio A/L Chemistry Public/Private A/L Physics  \
# ...

# %%
def z_data(value):
    if value>2.5:
        res=1
    elif value>2.0:
        res=2
    elif value>1.5:
        res=3
    elif value>1.0:
        res=4
    elif value>0.5:
        res=5
    elif value>0.0:
        res=6
    else:
        res=7
        
    return res

# %%
data['Z-core'] = data['Z-core'].apply(z_data)

# %%
sns.heatmap(data.isnull(),yticklabels=False, cmap="viridis")
# Out:
# <Axes: >

# %%
def subject_data(value):
    res="N"
    if value=="A":
        res=1
    elif value=="B":
        res=2
    elif value=="C":
        res=3
    elif value=="S":
        res=4
    else:
        res=5
        
    return res

# %%
data['O/L Maths'] = data['O/L Maths '].apply(subject_data)
data = data.drop(columns=['O/L Maths '])
data['O/L Science'] = data['O/L Science'].apply(subject_data)
data['O/L English'] = data['O/L  English '].apply(subject_data)
data = data.drop(columns=['O/L  English '])
data['A/L Combine Maths'] = data['A/L Combine Maths'].apply(subject_data)
data['A/L Bio'] = data['A/L Bio'].apply(subject_data)
data['A/L Chemistry'] = data['A/L Chemistry'].apply(subject_data)
data['A/L Physics'] = data['A/L Physics'].apply(subject_data)

# %%
data
# Out:
#       personality  Z-core  District  O/L Science  A/L Combine Maths  A/L Bio  \
# 0               1       5         7            1                  3        5
# 1               1       5        23            3                  2        5
# 2               1       5         8            2                  3        5
# 3               2       5         6            1                  2        5
# 4               2       5         6            2                  2        5
# ...           ...     ...       ...          ...                ...      ...
# 1509            3       7        17            1                  5        2
# 1510            3       7        16            1                  5        2
# 1511            3       7        15            1                  5        2
# 1512            3       7        14            1                  5        2
# 1513            3       7         1            1                  5        2
#
# ...

# %%
data['Public/Private']=data['Public/Private'].str.replace('Public','0')
data['Public/Private']=data['Public/Private'].str.replace('Private','1')

# %%
data
# Out:
#       personality  Z-core  District  O/L Science  A/L Combine Maths  A/L Bio  \
# 0               1       5         7            1                  3        5
# 1               1       5        23            3                  2        5
# 2               1       5         8            2                  3        5
# 3               2       5         6            1                  2        5
# 4               2       5         6            2                  2        5
# ...           ...     ...       ...          ...                ...      ...
# 1509            3       7        17            1                  5        2
# 1510            3       7        16            1                  5        2
# 1511            3       7        15            1                  5        2
# 1512            3       7        14            1                  5        2
# 1513            3       7         1            1                  5        2
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1514 entries, 0 to 1513
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   personality        1514 non-null   int64
#  1   Z-core             1514 non-null   int64
#  2   District           1514 non-null   int64
#  3   O/L Science        1514 non-null   int64
#  4   A/L Combine Maths  1514 non-null   int64
#  5   A/L Bio            1514 non-null   int64
#  6   A/L Chemistry      1514 non-null   int64
#  7   Public/Private     1514 non-null   object
#  8   A/L Physics        1514 non-null   int64
#  9   University         1514 non-null   int64
#  10  O/L Maths          1514 non-null   int64
#  11  O/L English        1514 non-null   int64
# dtypes: int64(11), object(1)
# memory usage: 142.1+ KB

# %%
data['Public/Private'] = data['Public/Private'].apply(np.int64)
data['University'] = data['University'].apply(np.int64)

# %%
X = data.drop('University', axis=1)
y = data['University']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# %%
X_train.shape, X.shape
# Out:
# ((1135, 11), (1514, 11))

# %%
def model_acc(model):
    model.fit(X_train, y_train)
    acc = model.score(X_test, y_test)
    print(str(model)+ ' --> ' +str(acc))

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
model_acc(lr)

from sklearn.linear_model import Lasso
lasso = Lasso()
model_acc(lasso)

from sklearn.tree import DecisionTreeRegressor
dt = DecisionTreeRegressor()
model_acc(dt)
# Out:
# LinearRegression() --> 0.1655081307967189
# Lasso() --> 0.049931536846028135
# DecisionTreeRegressor() --> 0.7404822860831375

# %%
import pickle
# save model to file
pickle.dump(dt, open("campus.dat", "wb"))

# %%
predict=np.round(dt.predict(X_test))

# %%
A = np.array(y_test).reshape(-1, 1)
B = predict.reshape(-1, 1)
print(type(predict))
print(type(y_test))
plt.rcParams['figure.figsize'] = 16,5
plt.figure()
plt.plot(A[-100:], label="Real")
plt.plot(B[-100:], label="Predicted")
plt.legend()
plt.title("Result : real vs predicted")
plt.ylabel("Result")
plt.xticks(())
plt.show()
# Out:
# <class 'numpy.ndarray'>
# <class 'pandas.core.series.Series'>

# %%
with open('campus.dat' , 'rb') as f:
    model = pickle.load(f)

# %%
data
# Out:
#       personality  Z-core  District  O/L Science  A/L Combine Maths  A/L Bio  \
# 0               1       5         7            1                  3        5
# 1               1       5        23            3                  2        5
# 2               1       5         8            2                  3        5
# 3               2       5         6            1                  2        5
# 4               2       5         6            2                  2        5
# ...           ...     ...       ...          ...                ...      ...
# 1509            3       7        17            1                  5        2
# 1510            3       7        16            1                  5        2
# 1511            3       7        15            1                  5        2
# 1512            3       7        14            1                  5        2
# 1513            3       7         1            1                  5        2
#
# ...

# %%
import math
math.ceil(model.predict([[1,7,2,1,4,5,4,1,4,4,4]]))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# 3
